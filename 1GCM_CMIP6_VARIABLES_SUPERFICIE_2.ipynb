# %% [markdown]
# <a href="https://colab.research.google.com/github/jotabruno/jotabruno/blob/main/1GCM_CMIP6_VARIABLES_SUPERFICIE_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/jotabruno/CLIMATE_CHANGE_CMIP6/blob/main/1GCM_CMIP6_VARIABLES_SUPERFICIE.ipynb
# )

# %%
import intake
import matplotlib.pyplot as plt
import xmip
from xmip.preprocessing import combined_preprocessing
import gcsfs
import numpy as np
import random
#test2

# %%
cat_url = "https://storage.googleapis.com/cmip6/pangeo-cmip6.json"
cat = intake.open_esm_datastore(cat_url)
cat.df
# Out:
#        activity_id       institution_id      source_id       experiment_id  \
# 0       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 1       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 2       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 3       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 4       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# ...            ...                  ...            ...                 ...
# 514813        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
# 514814        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
# 514815        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
# 514816        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
# 514817        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
#
#        member_id table_id variable_id grid_label  \
# 0       r1i1p1f1     Amon          ps         gn
# 1       r1i1p1f1     Amon        rsds         gn
# 2       r1i1p1f1     Amon        rlus         gn
# 3       r1i1p1f1     Amon        rlds         gn
# 4       r1i1p1f1     Amon         psl         gn
# ...          ...      ...         ...        ...
# 514813  r1i1p1f1     Amon         tas         gr
# 514814  r1i1p1f1     Amon        tauu         gr
# 514815  r1i1p1f1     Amon         hur         gr
# 514816  r1i1p1f1     Amon         hus         gr
# 514817  r1i1p1f1     Amon        tauv         gr
#
#                                                    zstore dcpp_init_year  \
# 0       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...           <NA>
# 1       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...           <NA>
# 2       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...           <NA>
# 3       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...           <NA>
# 4       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...           <NA>
# ...                                                   ...            ...
# 514813  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...           <NA>
# 514814  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...           <NA>
# 514815  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...           <NA>
# 514816  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...           <NA>
# 514817  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...           <NA>
#
#          version
# 0       20170706
# 1       20170706
# 2       20170706
# 3       20170706
# 4       20170706
# ...          ...
# 514813  20211207
# 514814  20211207
# 514815  20211207
# 514816  20211207
# 514817  20211207
#
# [514818 rows x 11 columns]

# %%
# Filtramos el catálogo para una variable, tabla, experimento y modelo específicos
cat2 = cat.search(
    variable_id = 'tas',        # temperatura superficial
    table_id = 'Amon',          # datos mensuales del océano
    experiment_id = 'historical',  # simulación histórica
    #source_id = ['ACCESS-CM2','MPI-ESM1-2-HR','NorESM2-MM','ECMWF-IFS-LR'],      # modelo
    source_id =[      'CMCC-CM2-HR4',      'EC-Earth3P-HR',    'HadGEM3-GC31-MM',
    'HadGEM3-GC31-HM',    'HadGEM3-GC31-LM',         'EC-Earth3P',
       'ECMWF-IFS-HR',       'ECMWF-IFS-LR',    'HadGEM3-GC31-LL',
      'CMCC-CM2-VHR4',           'GFDL-CM4',           'GFDL-AM4',
       'IPSL-CM6A-LR',           'E3SM-1-0',         'CNRM-CM6-1',
          'GFDL-ESM4',         'GFDL-ESM2M',       'GFDL-CM4C192',
        'GFDL-OM4p5B',        'GISS-E2-1-G',        'GISS-E2-1-H',
        'CNRM-ESM2-1',        'BCC-CSM2-MR',           'BCC-ESM1',
             'MIROC6',      'AWI-CM-1-1-MR',       'EC-Earth3-LR',
   'IPSL-CM6A-ATM-HR',              'CESM2',        'CESM2-WACCM',
      'CNRM-CM6-1-HR',         'MRI-ESM2-0',        'SAM0-UNICON',
     'GISS-E2-1-G-CC',        'UKESM1-0-LL',          'EC-Earth3',
      'EC-Earth3-Veg',        'FGOALS-f3-L',            'CanESM5',
      'CanESM5-CanOE',          'INM-CM4-8',          'INM-CM5-0',
              'NESM3',    'MPI-ESM-1-2-HAM',        'CAMS-CSM1-0',
      'MPI-ESM1-2-LR',      'MPI-ESM1-2-HR',      'MRI-AGCM3-2-H',
      'MRI-AGCM3-2-S',         'MCM-UA-1-0',          'INM-CM5-H',
         'KACE-1-0-G',         'NorESM2-LM',        'FGOALS-f3-H',
          'FGOALS-g3',         'MIROC-ES2L',        'FIO-ESM-2-0',
            'NorCPM1',          'NorESM1-F',      'MPI-ESM1-2-XR',
 'CESM1-1-CAM5-CMIP5',           'E3SM-1-1',          'KIOST-ESM',
         'ACCESS-CM2',         'NorESM2-MM',      'ACCESS-ESM1-5',
           'IITM-ESM',        'GISS-E2-2-G',          'CESM2-FV2',
        'GISS-E2-2-H',    'CESM2-WACCM-FV2',              'CIESM',
       'E3SM-1-1-ECA',            'TaiESM1',     'AWI-ESM-1-1-LR',
   'EC-Earth3-Veg-LR',          'CMCC-ESM2',       'CMCC-CM2-SR5',
  'EC-Earth3-AerChem',  'IPSL-CM6A-LR-INCA',    'IPSL-CM5A2-INCA',
        'BCC-CSM2-HR',     'EC-Earth3P-VHR',     'CESM1-WACCM-SC',
         'CAS-ESM2-0',       'EC-Earth3-CC',         'MIROC-ES2H',
        'ICON-ESM-LR'],
    member_id = ['r1i1p1f1'],      # miembro
    grid_label = 'gn'
)
# Mostramos el DataFrame resultante con los metadatos filtrados
cat2.df
# Out:
#    activity_id     institution_id        source_id experiment_id member_id  \
# 0         CMIP          NASA-GISS      GISS-E2-1-G    historical  r1i1p1f1
# 1         CMIP                BCC      BCC-CSM2-MR    historical  r1i1p1f1
# 2         CMIP              MIROC           MIROC6    historical  r1i1p1f1
# 3         CMIP                BCC         BCC-ESM1    historical  r1i1p1f1
# 4         CMIP                MRI       MRI-ESM2-0    historical  r1i1p1f1
# 5         CMIP               NCAR      CESM2-WACCM    historical  r1i1p1f1
# 6         CMIP               NCAR            CESM2    historical  r1i1p1f1
# 7         CMIP                SNU      SAM0-UNICON    historical  r1i1p1f1
# 8         CMIP          NASA-GISS      GISS-E2-1-H    historical  r1i1p1f1
# 9         CMIP              CCCma          CanESM5    historical  r1i1p1f1
# 10        CMIP  HAMMOZ-Consortium  MPI-ESM-1-2-HAM    historical  r1i1p1f1
# 11        CMIP              NUIST            NESM3    historical  r1i1p1f1
# 12        CMIP               CAMS      CAMS-CSM1-0    historical  r1i1p1f1
# 13        CMIP              MPI-M    MPI-ESM1-2-LR    historical  r1i1p1f1
# 14        CMIP              MPI-M    MPI-ESM1-2-HR    historical  r1i1p1f1
# 15        CMIP                 UA       MCM-UA-1-0    historical  r1i1p1f1
# 16        CMIP          NASA-GISS   GISS-E2-1-G-CC    historical  r1i1p1f1
# 17        CMIP                NCC       NorESM2-LM    historical  r1i1p1f1
# 18        CMIP                CAS        FGOALS-g3    historical  r1i1p1f1
# 19        CMIP       CSIRO-ARCCSS       ACCESS-CM2    historical  r1i1p1f1
# 20        CMIP                NCC       NorESM2-MM    historical  r1i1p1f1
# 21        CMIP           FIO-QLNM      FIO-ESM-2-0    historical  r1i1p1f1
# 22        CMIP              CSIRO    ACCESS-ESM1-5    historical  r1i1p1f1
# 23        CMIP               NCAR        CESM2-FV2    historical  r1i1p1f1
# 24        CMIP          NASA-GISS      GISS-E2-2-H    historical  r1i1p1f1
# 25        CMIP               NCAR  CESM2-WACCM-FV2    historical  r1i1p1f1
# 26        CMIP          CCCR-IITM         IITM-ESM    historical  r1i1p1f1
# 27        CMIP                AWI   AWI-ESM-1-1-LR    historical  r1i1p1f1
# 28        CMIP               CMCC     CMCC-CM2-SR5    historical  r1i1p1f1
# 29        CMIP            AS-RCEC          TaiESM1    historical  r1i1p1f1
# 30        CMIP                AWI    AWI-CM-1-1-MR    historical  r1i1p1f1
# 31        CMIP                NCC          NorCPM1    historical  r1i1p1f1
# 32        CMIP               CMCC     CMCC-CM2-HR4    historical  r1i1p1f1
# 33        CMIP                CAS       CAS-ESM2-0    historical  r1i1p1f1
# 34        CMIP               CMCC        CMCC-ESM2    historical  r1i1p1f1
# 35        CMIP              MPI-M      ICON-ESM-LR    historical  r1i1p1f1
#
#    table_id variable_id grid_label  \
# 0      Amon         tas         gn
# 1      Amon         tas         gn
# 2      Amon         tas         gn
# 3      Amon         tas         gn
# 4      Amon         tas         gn
# 5      Amon         tas         gn
# 6      Amon         tas         gn
# 7      Amon         tas         gn
# 8      Amon         tas         gn
# 9      Amon         tas         gn
# 10     Amon         tas         gn
# 11     Amon         tas         gn
# 12     Amon         tas         gn
# 13     Amon         tas         gn
# 14     Amon         tas         gn
# 15     Amon         tas         gn
# 16     Amon         tas         gn
# 17     Amon         tas         gn
# 18     Amon         tas         gn
# 19     Amon         tas         gn
# 20     Amon         tas         gn
# 21     Amon         tas         gn
# 22     Amon         tas         gn
# 23     Amon         tas         gn
# 24     Amon         tas         gn
# 25     Amon         tas         gn
# 26     Amon         tas         gn
# 27     Amon         tas         gn
# 28     Amon         tas         gn
# 29     Amon         tas         gn
# 30     Amon         tas         gn
# 31     Amon         tas         gn
# 32     Amon         tas         gn
# 33     Amon         tas         gn
# 34     Amon         tas         gn
# 35     Amon         tas         gn
#
#                                                zstore dcpp_init_year   version
# 0   gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G/hi...           <NA>  20180827
# 1   gs://cmip6/CMIP6/CMIP/BCC/BCC-CSM2-MR/historic...           <NA>  20181126
# 2   gs://cmip6/CMIP6/CMIP/MIROC/MIROC6/historical/...           <NA>  20181212
# 3   gs://cmip6/CMIP6/CMIP/BCC/BCC-ESM1/historical/...           <NA>  20181214
# 4   gs://cmip6/CMIP6/CMIP/MRI/MRI-ESM2-0/historica...           <NA>  20190222
# 5   gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/histori...           <NA>  20190227
# 6   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...           <NA>  20190308
# 7   gs://cmip6/CMIP6/CMIP/SNU/SAM0-UNICON/historic...           <NA>  20190323
# 8   gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-H/hi...           <NA>  20190403
# 9   gs://cmip6/CMIP6/CMIP/CCCma/CanESM5/historical...           <NA>  20190429
# 10  gs://cmip6/CMIP6/CMIP/HAMMOZ-Consortium/MPI-ES...           <NA>  20190627
# 11  gs://cmip6/CMIP6/CMIP/NUIST/NESM3/historical/r...           <NA>  20190630
# 12  gs://cmip6/CMIP6/CMIP/CAMS/CAMS-CSM1-0/histori...           <NA>  20190708
# 13  gs://cmip6/CMIP6/CMIP/MPI-M/MPI-ESM1-2-LR/hist...           <NA>  20190710
# 14  gs://cmip6/CMIP6/CMIP/MPI-M/MPI-ESM1-2-HR/hist...           <NA>  20190710
# 15  gs://cmip6/CMIP6/CMIP/UA/MCM-UA-1-0/historical...           <NA>  20190731
# 16  gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G-CC...           <NA>  20190815
# 17  gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/historica...           <NA>  20190815
# 18  gs://cmip6/CMIP6/CMIP/CAS/FGOALS-g3/historical...           <NA>  20190818
# 19  gs://cmip6/CMIP6/CMIP/CSIRO-ARCCSS/ACCESS-CM2/...           <NA>  20191108
# 20  gs://cmip6/CMIP6/CMIP/NCC/NorESM2-MM/historica...           <NA>  20191108
# 21  gs://cmip6/CMIP6/CMIP/FIO-QLNM/FIO-ESM-2-0/his...           <NA>  20191115
# 22  gs://cmip6/CMIP6/CMIP/CSIRO/ACCESS-ESM1-5/hist...           <NA>  20191115
# 23  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-FV2/historica...           <NA>  20191120
# 24  gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-2-H/hi...           <NA>  20191120
# 25  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/his...           <NA>  20191120
# 26  gs://cmip6/CMIP6/CMIP/CCCR-IITM/IITM-ESM/histo...           <NA>  20191226
# 27  gs://cmip6/CMIP6/CMIP/AWI/AWI-ESM-1-1-LR/histo...           <NA>  20200212
# 28  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-CM2-SR5/histor...           <NA>  20200616
# 29  gs://cmip6/CMIP6/CMIP/AS-RCEC/TaiESM1/historic...           <NA>  20200623
# 30  gs://cmip6/CMIP6/CMIP/AWI/AWI-CM-1-1-MR/histor...           <NA>  20200720
# 31  gs://cmip6/CMIP6/CMIP/NCC/NorCPM1/historical/r...           <NA>  20200724
# 32  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-CM2-HR4/histor...           <NA>  20200904
# 33  gs://cmip6/CMIP6/CMIP/CAS/CAS-ESM2-0/historica...           <NA>  20201227
# 34  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-ESM2/historica...           <NA>  20210114
# 35  gs://cmip6/CMIP6/CMIP/MPI-M/ICON-ESM-LR/histor...           <NA>  20210215

# %%
# 2. Abrir todos los modelos (36)
# ==============================
ds_dict_full = cat2.to_dataset_dict(
    zarr_kwargs={"consolidated": True}
)
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='36' class='' max='36' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [36/36 00:28&lt;00:00]
#     </div>

# %%
for key, ds in ds_dict_full.items():
    print("="*80)
    print(key)
    print("source_id:", ds.attrs.get("source_id"))
    print("dims:", ds.dims)
    print("coords:", list(ds.coords))
    print("tas dims:", ds["tas"].dims)
    print("tas shape:", ds["tas"].shape)
# Out:
# ================================================================================
# CMIP.CAS.FGOALS-g3.historical.Amon.gn
# source_id: FGOALS-g3
# dims: FrozenMappingWarningOnValuesAccess({'lat': 80, 'bnds': 2, 'lon': 180, 'member_id': 1, 'dcpp_init_year': 1, 'time': 2004})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 2004, 80, 180)
# ================================================================================
# CMIP.MRI.MRI-ESM2-0.historical.Amon.gn
# source_id: MRI-ESM2-0
# dims: FrozenMappingWarningOnValuesAccess({'lat': 160, 'bnds': 2, 'lon': 320, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 160, 320)
# ================================================================================
# CMIP.NASA-GISS.GISS-E2-2-H.historical.Amon.gn
# source_id: GISS-E2-2-H
# dims: FrozenMappingWarningOnValuesAccess({'lat': 90, 'bnds': 2, 'lon': 144, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 90, 144)
# ================================================================================
# CMIP.AWI.AWI-CM-1-1-MR.historical.Amon.gn
# source_id: AWI-CM-1-1-MR
# dims: FrozenMappingWarningOnValuesAccess({'lat': 192, 'bnds': 2, 'lon': 384, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1968})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1968, 192, 384)
# ================================================================================
# CMIP.NASA-GISS.GISS-E2-1-G.historical.Amon.gn
# source_id: GISS-E2-1-G
# dims: FrozenMappingWarningOnValuesAccess({'lat': 90, 'bnds': 2, 'lon': 144, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 90, 144)
# ================================================================================
# CMIP.MPI-M.MPI-ESM1-2-HR.historical.Amon.gn
# source_id: MPI-ESM1-2-HR
# dims: FrozenMappingWarningOnValuesAccess({'lat': 192, 'bnds': 2, 'lon': 384, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 192, 384)
# ================================================================================
# CMIP.NASA-GISS.GISS-E2-1-G-CC.historical.Amon.gn
# source_id: GISS-E2-1-G-CC
# dims: FrozenMappingWarningOnValuesAccess({'lat': 90, 'bnds': 2, 'lon': 144, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 90, 144)
# ================================================================================
# CMIP.MPI-M.ICON-ESM-LR.historical.Amon.gn
# source_id: ICON-ESM-LR
# dims: FrozenMappingWarningOnValuesAccess({'i': 20480, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980, 'bnds': 2, 'vertices': 3})
# coords: ['height', 'i', 'latitude', 'longitude', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'i')
# tas shape: (1, 1, 1980, 20480)
# ================================================================================
# CMIP.CMCC.CMCC-CM2-HR4.historical.Amon.gn
# source_id: CMCC-CM2-HR4
# dims: FrozenMappingWarningOnValuesAccess({'lat': 192, 'bnds': 2, 'lon': 288, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 192, 288)
# ================================================================================
# CMIP.MPI-M.MPI-ESM1-2-LR.historical.Amon.gn
# source_id: MPI-ESM1-2-LR
# dims: FrozenMappingWarningOnValuesAccess({'lat': 96, 'bnds': 2, 'lon': 192, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 96, 192)
# ================================================================================
# CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.Amon.gn
# source_id: ACCESS-CM2
# dims: FrozenMappingWarningOnValuesAccess({'lat': 144, 'bnds': 2, 'lon': 192, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 144, 192)
# ================================================================================
# CMIP.NCC.NorESM2-MM.historical.Amon.gn
# source_id: NorESM2-MM
# dims: FrozenMappingWarningOnValuesAccess({'lat': 192, 'bnds': 2, 'lon': 288, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 192, 288)
# ================================================================================
# CMIP.CCCR-IITM.IITM-ESM.historical.Amon.gn
# source_id: IITM-ESM
# dims: FrozenMappingWarningOnValuesAccess({'lat': 94, 'bnds': 2, 'lon': 192, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 94, 192)
# ================================================================================
# CMIP.FIO-QLNM.FIO-ESM-2-0.historical.Amon.gn
# source_id: FIO-ESM-2-0
# dims: FrozenMappingWarningOnValuesAccess({'lat': 192, 'bnds': 2, 'lon': 288, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 192, 288)
# ================================================================================
# CMIP.CAMS.CAMS-CSM1-0.historical.Amon.gn
# source_id: CAMS-CSM1-0
# dims: FrozenMappingWarningOnValuesAccess({'lat': 160, 'bnds': 2, 'lon': 320, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 160, 320)
# ================================================================================
# CMIP.NASA-GISS.GISS-E2-1-H.historical.Amon.gn
# source_id: GISS-E2-1-H
# dims: FrozenMappingWarningOnValuesAccess({'lat': 90, 'bnds': 2, 'lon': 144, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 90, 144)
# ================================================================================
# CMIP.NUIST.NESM3.historical.Amon.gn
# source_id: NESM3
# dims: FrozenMappingWarningOnValuesAccess({'lat': 96, 'bnds': 2, 'lon': 192, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 96, 192)
# ================================================================================
# CMIP.NCAR.CESM2-WACCM.historical.Amon.gn
# source_id: CESM2-WACCM
# dims: FrozenMappingWarningOnValuesAccess({'lat': 192, 'nbnd': 2, 'lon': 288, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 192, 288)
# ================================================================================
# CMIP.CMCC.CMCC-ESM2.historical.Amon.gn
# source_id: CMCC-ESM2
# dims: FrozenMappingWarningOnValuesAccess({'lat': 192, 'bnds': 2, 'lon': 288, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 192, 288)
# ================================================================================
# CMIP.NCAR.CESM2.historical.Amon.gn
# source_id: CESM2
# dims: FrozenMappingWarningOnValuesAccess({'lat': 192, 'nbnd': 2, 'lon': 288, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 192, 288)
# ================================================================================
# CMIP.NCC.NorCPM1.historical.Amon.gn
# source_id: NorCPM1
# dims: FrozenMappingWarningOnValuesAccess({'lat': 96, 'bnds': 2, 'lon': 144, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 96, 144)
# ================================================================================
# CMIP.SNU.SAM0-UNICON.historical.Amon.gn
# source_id: SAM0-UNICON
# dims: FrozenMappingWarningOnValuesAccess({'lat': 192, 'bnds': 2, 'lon': 288, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 192, 288)
# ================================================================================
# CMIP.NCAR.CESM2-FV2.historical.Amon.gn
# source_id: CESM2-FV2
# dims: FrozenMappingWarningOnValuesAccess({'lat': 96, 'nbnd': 2, 'lon': 144, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 96, 144)
# ================================================================================
# CMIP.UA.MCM-UA-1-0.historical.Amon.gn
# source_id: MCM-UA-1-0
# dims: FrozenMappingWarningOnValuesAccess({'latitude': 80, 'longitude': 96, 'bnds': 2, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['bnds', 'lat_bnds', 'latitude', 'lon_bnds', 'longitude', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'latitude', 'longitude')
# tas shape: (1, 1, 1980, 80, 96)
# ================================================================================
# CMIP.AWI.AWI-ESM-1-1-LR.historical.Amon.gn
# source_id: AWI-ESM-1-1-LR
# dims: FrozenMappingWarningOnValuesAccess({'lat': 96, 'bnds': 2, 'lon': 192, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 96, 192)
# ================================================================================
# CMIP.NCC.NorESM2-LM.historical.Amon.gn
# source_id: NorESM2-LM
# dims: FrozenMappingWarningOnValuesAccess({'lat': 96, 'bnds': 2, 'lon': 144, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 96, 144)
# ================================================================================
# CMIP.CCCma.CanESM5.historical.Amon.gn
# source_id: CanESM5
# dims: FrozenMappingWarningOnValuesAccess({'lat': 64, 'bnds': 2, 'lon': 128, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 64, 128)
# ================================================================================
# CMIP.MIROC.MIROC6.historical.Amon.gn
# source_id: MIROC6
# dims: FrozenMappingWarningOnValuesAccess({'lat': 128, 'bnds': 2, 'lon': 256, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 128, 256)
# ================================================================================
# CMIP.NCAR.CESM2-WACCM-FV2.historical.Amon.gn
# source_id: CESM2-WACCM-FV2
# dims: FrozenMappingWarningOnValuesAccess({'lat': 96, 'nbnd': 2, 'lon': 144, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 96, 144)
# ================================================================================
# CMIP.BCC.BCC-ESM1.historical.Amon.gn
# source_id: BCC-ESM1
# dims: FrozenMappingWarningOnValuesAccess({'lat': 64, 'bnds': 2, 'lon': 128, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 64, 128)
# ================================================================================
# CMIP.CAS.CAS-ESM2-0.historical.Amon.gn
# source_id: CAS-ESM2-0
# dims: FrozenMappingWarningOnValuesAccess({'lat': 128, 'bnds': 2, 'lon': 256, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 128, 256)
# ================================================================================
# CMIP.AS-RCEC.TaiESM1.historical.Amon.gn
# source_id: TaiESM1
# dims: FrozenMappingWarningOnValuesAccess({'lat': 192, 'bnds': 2, 'lon': 288, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 192, 288)
# ================================================================================
# CMIP.CSIRO.ACCESS-ESM1-5.historical.Amon.gn
# source_id: ACCESS-ESM1-5
# dims: FrozenMappingWarningOnValuesAccess({'lat': 145, 'bnds': 2, 'lon': 192, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 145, 192)
# ================================================================================
# CMIP.HAMMOZ-Consortium.MPI-ESM-1-2-HAM.historical.Amon.gn
# source_id: MPI-ESM-1-2-HAM
# dims: FrozenMappingWarningOnValuesAccess({'lat': 96, 'bnds': 2, 'lon': 192, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 96, 192)
# ================================================================================
# CMIP.CMCC.CMCC-CM2-SR5.historical.Amon.gn
# source_id: CMCC-CM2-SR5
# dims: FrozenMappingWarningOnValuesAccess({'lat': 192, 'bnds': 2, 'lon': 288, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 192, 288)
# ================================================================================
# CMIP.BCC.BCC-CSM2-MR.historical.Amon.gn
# source_id: BCC-CSM2-MR
# dims: FrozenMappingWarningOnValuesAccess({'lat': 160, 'bnds': 2, 'lon': 320, 'member_id': 1, 'dcpp_init_year': 1, 'time': 1980})
# coords: ['height', 'lat', 'lat_bnds', 'lon', 'lon_bnds', 'time', 'time_bnds', 'member_id', 'dcpp_init_year']
# tas dims: ('member_id', 'dcpp_init_year', 'time', 'lat', 'lon')
# tas shape: (1, 1, 1980, 160, 320)

# %% [markdown]
# ## PLOT SUDAMERICA ##

# %%
# ==============================
# 3. Dominio Sudamérica
# ==============================
lon_min, lon_max = -90, -30
lat_min, lat_max = -60, 15

# ==============================
# 4. Filtrar modelos realmente ploteables
# ==============================
valid_items = []

for key, ds in ds_dict_full.items():

    tas = ds["tas"]

    # debe ser lat-lon
    if not {"lat", "lon"}.issubset(tas.dims):
        continue

    tas = tas.squeeze().mean(dim="time", skipna=True) - 273.15

    # convertir longitudes 0–360 → −180–180 si aplica
    if tas.lon.max() > 180:
        tas = tas.assign_coords(
            lon=((tas.lon + 180) % 360) - 180
        ).sortby("lon")

    # probar recorte Sudamérica
    tas_sa = tas.sel(
        lon=slice(lon_min, lon_max),
        lat=slice(lat_min, lat_max)
    )

    # dominio no vacío
    if tas_sa.lon.size == 0 or tas_sa.lat.size == 0:
        continue

    valid_items.append((key, ds))

print(f"Modelos válidos para Sudamérica: {len(valid_items)}")

# ==============================
# 5. Seleccionar EXACTAMENTE 10
# ==============================
random.seed(42)
selected_items = random.sample(valid_items, 10)
ds_dict = dict(selected_items)

# ==============================
# 6. Figura fija 2 × 5
# ==============================
fig, axes = plt.subplots(2, 5, figsize=(25, 10))
axes = axes.flatten()

im = None

# ==============================
# 7. Loop de mapas
# ==============================
for ax, (key, ds) in zip(axes, ds_dict.items()):

    src = ds.attrs.get("source_id", "unknown")

    tas = ds["tas"].squeeze().mean(dim="time", skipna=True) - 273.15

    if tas.lon.max() > 180:
        tas = tas.assign_coords(
            lon=((tas.lon + 180) % 360) - 180
        ).sortby("lon")

    tas_sa = tas.sel(
        lon=slice(lon_min, lon_max),
        lat=slice(lat_min, lat_max)
    )

    im = ax.pcolormesh(
        tas_sa.lon,
        tas_sa.lat,
        tas_sa,
        cmap="RdBu_r",
        shading="auto"
    )

    ax.set_xlim(lon_min, lon_max)
    ax.set_ylim(lat_min, lat_max)
    ax.set_title(src, fontsize=10)

# ==============================
# 8. Layout
# ==============================
fig.subplots_adjust(
    left=0.05,
    right=0.98,
    top=0.90,
    bottom=0.18,
    wspace=0.15,
    hspace=0.25
)

# ==============================
# 9. Barra de colores inferior
# ==============================
cax = fig.add_axes([0.25, 0.08, 0.5, 0.03])
cbar = fig.colorbar(im, cax=cax, orientation="horizontal")
cbar.set_label("Temperatura superficial (°C)")

# ==============================
# 10. Título
# ==============================
fig.suptitle(
    "Temperatura superficial media (tas) – Sudamérica\n10 modelos CMIP6 (histórico)",
    fontsize=16
)

plt.show()
# Out:
# Modelos válidos para Sudamérica: 34

# %% [markdown]
# ## PLOT PERU ##

# %%
# ==============================
# 3. Dominio Perú
# ==============================
lon_min, lon_max = -82, -68
lat_min, lat_max = -19, 1

# ==============================
# 4. Filtrar modelos ploteables en Perú
# ==============================
valid_items = []

for key, ds in ds_dict_full.items():

    tas = ds["tas"]

    # debe tener lat-lon
    if not {"lat", "lon"}.issubset(tas.dims):
        continue

    # media temporal
    tas_map = tas.squeeze().mean(dim="time", skipna=True) - 273.15

    # convertir longitudes 0–360 → −180–180
    if tas_map.lon.max() > 180:
        tas_map = tas_map.assign_coords(
            lon=((tas_map.lon + 180) % 360) - 180
        ).sortby("lon")

    # recorte Perú
    tas_pe = tas_map.sel(
        lon=slice(lon_min, lon_max),
        lat=slice(lat_min, lat_max)
    )

    # dominio válido
    if tas_pe.lon.size == 0 or tas_pe.lat.size == 0:
        continue

    valid_items.append((key, ds))

print(f"Modelos válidos para Perú: {len(valid_items)}")

# ==============================
# 5. Seleccionar EXACTAMENTE 10
# ==============================
random.seed(42)
selected_items = random.sample(valid_items, 10)
ds_dict = dict(selected_items)

# ==============================
# 6. Figura 2 × 5
# ==============================
fig, axes = plt.subplots(2, 5, figsize=(25, 10))
axes = axes.flatten()

im = None

# ==============================
# 7. Loop de mapas
# ==============================
for ax, (key, ds) in zip(axes, ds_dict.items()):

    src = ds.attrs.get("source_id", "unknown")

    tas = ds["tas"].squeeze().mean(dim="time", skipna=True) - 273.15

    if tas.lon.max() > 180:
        tas = tas.assign_coords(
            lon=((tas.lon + 180) % 360) - 180
        ).sortby("lon")

    tas_pe = tas.sel(
        lon=slice(lon_min, lon_max),
        lat=slice(lat_min, lat_max)
    )

    im = ax.pcolormesh(
        tas_pe.lon,
        tas_pe.lat,
        tas_pe,
        cmap="RdBu_r",
        shading="auto"
    )

    ax.set_xlim(lon_min, lon_max)
    ax.set_ylim(lat_min, lat_max)
    ax.set_title(src, fontsize=10)

# ==============================
# 8. Layout
# ==============================
fig.subplots_adjust(
    left=0.05,
    right=0.98,
    top=0.90,
    bottom=0.18,
    wspace=0.15,
    hspace=0.25
)

# ==============================
# 9. Barra de colores inferior
# ==============================
cax = fig.add_axes([0.25, 0.08, 0.5, 0.03])
cbar = fig.colorbar(im, cax=cax, orientation="horizontal")
cbar.set_label("Temperatura superficial (°C)")

# ==============================
# 10. Título
# ==============================
fig.suptitle(
    "Temperatura superficial media (tas) – Perú\n10 modelos CMIP6 (histórico)",
    fontsize=16
)

plt.show()
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='36' class='' max='36' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [36/36 00:31&lt;00:00]
#     </div>
# Modelos válidos para Perú: 34
